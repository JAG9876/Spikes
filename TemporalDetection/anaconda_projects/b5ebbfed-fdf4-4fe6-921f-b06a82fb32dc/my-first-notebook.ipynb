# %%
import sys
sys.path.append(r'C:\repos\Spikes\TemporalDetection')

# %%
from test_temporal_detection import *

# %%
# %%debug
# # Run test
# test_get_offset(r'C:\repos\Spikes\TemporalDetection\test_files\audio\OneClapPianoMobile.wav', r'C:\repos\Spikes\TemporalDetection\test_files\audio\OneClapStuebordPCMono.wav', 1.953, td.Algorithm.ARGMAX)
# Out:
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > <string>(3)<module>()
# ipdb>  s
# --Call--
# > c:\repos\spikes\temporaldetection\test_temporal_detection.py(6)test_get_offset()
#       4 import time
#       5
# ----> 6 @pytest.mark.parametrize("wavfile1, wavfile2, full_expected_offset, algorithm", [
#       7         # < 1 second
#       8         ('test_files\\audio\\OneClapPianoMobile.wav', 'test_files\\audio\\OneClapStuebordPCMono.wav', 1.953, td.Algorithm.ARGMAX),
# ipdb>  s
# > c:\repos\spikes\temporaldetection\test_temporal_detection.py(17)test_get_offset()
#      15     ])
#      16 def test_get_offset(wavfile1, wavfile2, full_expected_offset, algorithm: td.Algorithm):
# ---> 17     wave1 = wavfile.read(wavfile1)
#      18     assert 1 == 0
#      19
# ipdb>  wave1
# *** NameError: name 'wave1' is not defined
# ipdb>  s
# --Call--
# > c:\users\pej\anaconda3\lib\site-packages\scipy\io\wavfile.py(609)read()
#     607
#     608
# ...
